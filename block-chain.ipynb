# %% [markdown]
# ## PURNA JAIN

# %% [markdown]
# ## BLOCKCHAIN SIMULATOR

# %%
import hashlib                 
import datetime as date        
import random  
class Block():
    def __init__(self, height, timestamp, prev_hash, txs):
        self.height = height
        self.timestamp = timestamp
        self.prev_hash = prev_hash
        self.hash = self.hash_block()
        self.transactions = txs
        self.tx_ctr = len(txs)
        self.merkle = self.merkle_root_hash(self.transactions)
        
    def hashing(self, string):
        string = string.encode()
        sha = hashlib.sha256(string).hexdigest()
        return sha
    def hash_block(self):
        string = str(self.height) + str(self.timestamp) + str(self.prev_hash)
        return self.hashing(string)
    def merkle_root_hash(self, txs):
        if (len(txs) == 1):
            return txs[0]
        txs_new = []
        for i in range(0, len(txs)-1, 2):
            txs_new.append(self.hashing(str(txs[i]) + str(txs[i+1])))
        if len(txs)%2 == 1:
            txs_new.append(self.hashing(str(txs[-1]) + str(txs[-1])))
        return self.merkle_root_hash(txs_new)
def create_genesis_block():
    return Block(0, date.datetime.now(), "0", [random.randint(1,1000) for _ in range(10)])
def next_block(last_block):
    this_height = last_block.height + 1
    this_timestamp = date.datetime.now()
    this_hash = last_block.hash
    this_txs = [random.randint(1,100) for _ in range(10)]
    return Block(this_height, this_timestamp, this_hash, this_txs)
if __name__=="__main__":
    Myblockchain = [create_genesis_block()]
    previous_block = Myblockchain[0]
    no_of_block = 10
for i in range(1, no_of_block +1):
    block_addition = next_block(previous_block)
    Myblockchain.append(block_addition)
    previous_block = block_addition
    print(
        (f"\nBlock #{i} has been added to the Myblockchain!\n"),
        ("\t\t{}\n".format("_"*10)),
        (f"\t\tHash: {block_addition.hash}"),
        (f"| Height of Block: {block_addition.height}"),
        (f"| Timestamp: {block_addition.timestamp}"),
        (f"| Previous Root Hash: {block_addition.prev_hash}"),
        (f"| Transactions: {block_addition.transactions}"),
        (f"| Transaction Counter: {block_addition.tx_ctr}"),
        (f"| Merkle Root Hash: {block_addition.merkle}"),
        ("\t\t{}".format("_"*10))
    )
# Out:
# Block #1 has been added to the Myblockchain!
#  		__________
#  		Hash: 6e9d17b48044fc52d4c17baec192a5b3f08206af259d77281132ea3bb0aa7d69 | Height of Block: 1 | Timestamp: 2021-08-17 18:00:05.580969 | Previous Root Hash: 61add63c6647562cdb72ae09a13b45338ac226ead9839070ecc0d875f35c76b3 | Transactions: [90, 36, 65, 97, 30, 98, 95, 66, 53, 42] | Transaction Counter: 10 | Merkle Root Hash: 31a73730539b42de1879796d9f97e88812ae430874a1ca050bb4c37fc6659413 		__________
#
# Block #2 has been added to the Myblockchain!
#  		__________
#  		Hash: 0e8fd8fe7dd9d7b67fd41571bc65f665fe534bbc556a6dcc3f544c9ca665cc6e | Height of Block: 2 | Timestamp: 2021-08-17 18:00:05.581488 | Previous Root Hash: 6e9d17b48044fc52d4c17baec192a5b3f08206af259d77281132ea3bb0aa7d69 | Transactions: [20, 86, 66, 72, 31, 68, 89, 64, 42, 64] | Transaction Counter: 10 | Merkle Root Hash: b5127a080f9f688ade297995fe460a92a92fa3990fd8a1ea392d37e995b8876c 		__________
#
# Block #3 has been added to the Myblockchain!
#  		__________
#  		Hash: b5e74dc4ccfb1e9a93fe37ca01e127e1d4495a7647b45d20a64e8d46a710b876 | Height of Block: 3 | Timestamp: 2021-08-17 18:00:05.583310 | Previous Root Hash: 0e8fd8fe7dd9d7b67fd41571bc65f665fe534bbc556a6dcc3f544c9ca665cc6e | Transactions: [80, 53, 80, 16, 74, 59, 79, 90, 74, 37] | Transaction Counter: 10 | Merkle Root Hash: 55e81fe0ad2f0da58a4ded4b5301c55f34d9b5521317b43dc18bacd7680ab329 		__________
#
# Block #4 has been added to the Myblockchain!
#  		__________
#  		Hash: 0997b5a172d61f4e4b3edc37bc28b4bb7ab75d6c91c5e9c2f9377a858f435817 | Height of Block: 4 | Timestamp: 2021-08-17 18:00:05.583710 | Previous Root Hash: b5e74dc4ccfb1e9a93fe37ca01e127e1d4495a7647b45d20a64e8d46a710b876 | Transactions: [44, 84, 92, 10, 19, 21, 62, 70, 52, 92] | Transaction Counter: 10 | Merkle Root Hash: 386b938c04adee53a27e6858af37e40bf5d9134681a52221f0a1b8b2ece6b9a7 		__________
#
# Block #5 has been added to the Myblockchain!
#  		__________
#  		Hash: f1d1a4d6f8c6abe5d151035bc2a7d15466620a86a4fa07234abe18f8afee3e90 | Height of Block: 5 | Timestamp: 2021-08-17 18:00:05.584020 | Previous Root Hash: 0997b5a172d61f4e4b3edc37bc28b4bb7ab75d6c91c5e9c2f9377a858f435817 | Transactions: [6, 30, 9, 77, 83, 53, 38, 17, 40, 28] | Transaction Counter: 10 | Merkle Root Hash: 74facc34280d63ed8a490bf5931c7a9967dd4dd1c6a6bd37d4035bed86aebe8f 		__________
#
# Block #6 has been added to the Myblockchain!
#  		__________
#  		Hash: 5c73cb40ad683a627fd0a8fc3fa116fd6f031d4ac5e9bc04b1ed59c94e916ca7 | Height of Block: 6 | Timestamp: 2021-08-17 18:00:05.587267 | Previous Root Hash: f1d1a4d6f8c6abe5d151035bc2a7d15466620a86a4fa07234abe18f8afee3e90 | Transactions: [6, 17, 35, 48, 61, 19, 78, 53, 49, 59] | Transaction Counter: 10 | Merkle Root Hash: 8672fca6057852e1659ed3c59712638f991f9513d1e12d38c08d45ccbb8f3e8e 		__________
#
# Block #7 has been added to the Myblockchain!
#  		__________
#  		Hash: 7eb096096f719775cef5d1bf88669f9624741222989320b6a8ce8058e039169e | Height of Block: 7 | Timestamp: 2021-08-17 18:00:05.588270 | Previous Root Hash: 5c73cb40ad683a627fd0a8fc3fa116fd6f031d4ac5e9bc04b1ed59c94e916ca7 | Transactions: [78, 28, 12, 76, 75, 29, 90, 73, 46, 53] | Transaction Counter: 10 | Merkle Root Hash: 37e2f00243a765ec702d936fad5a58fae06684bcd868e499d7eec2975e01d1c6 		__________
#
# Block #8 has been added to the Myblockchain!
#  		__________
#  		Hash: dd4e48832a8c716712d207ed43d85a27aac1b0e29dba7a1af3c0818a50b1c5e4 | Height of Block: 8 | Timestamp: 2021-08-17 18:00:05.590417 | Previous Root Hash: 7eb096096f719775cef5d1bf88669f9624741222989320b6a8ce8058e039169e | Transactions: [45, 100, 14, 36, 60, 77, 50, 76, 84, 73] | Transaction Counter: 10 | Merkle Root Hash: 9989ca5237f4b7427e278e4dc7e156271e91ea73476d20013ff5f67a8f042a56 		__________
#
# Block #9 has been added to the Myblockchain!
#  		__________
#  		Hash: bfe96dae4b5436802e4ca39a03f400f1eb5f49fd32243fbd4a3a5e1cfc0740c4 | Height of Block: 9 | Timestamp: 2021-08-17 18:00:05.590727 | Previous Root Hash: dd4e48832a8c716712d207ed43d85a27aac1b0e29dba7a1af3c0818a50b1c5e4 | Transactions: [6, 12, 24, 27, 62, 33, 68, 62, 13, 76] | Transaction Counter: 10 | Merkle Root Hash: 31d4a3038376aeb4b62318a00dd85aaafa628e424ac3ceeb3c2385ba6f2b27c6 		__________
#
# Block #10 has been added to the Myblockchain!
#  		__________
#  		Hash: 019fd132ed4bbc637c6ab3cb6b8b04635f2bda5df2ad23fbc9f2e22ca6c54f1d | Height of Block: 10 | Timestamp: 2021-08-17 18:00:05.593519 | Previous Root Hash: bfe96dae4b5436802e4ca39a03f400f1eb5f49fd32243fbd4a3a5e1cfc0740c4 | Transactions: [59, 7, 62, 89, 67, 99, 81, 98, 60, 53] | Transaction Counter: 10 | Merkle Root Hash: d8bc2cacc12a979078ef6a94a42643301fd85831e255eef56782b9249b2587f2 		__________
